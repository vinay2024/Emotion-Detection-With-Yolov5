# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
pwd
# Out:
# '/content'

# %%
# %cd /content/gdrive/MyDrive/
# Out:
# /content/gdrive/MyDrive

# %%
# %cd EMO_1
# Out:
# /content/gdrive/MyDrive/EMO_1

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd yolov5
# Out:
# /content/gdrive/MyDrive/EMO_1/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 68.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 53.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.
# ...

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv

# %%
pwd
# Out:
# '/content/gdrive/MyDrive/EMO_1/yolov5'

# %%
model = torch.hub.load('ultralytics/yolov5','yolov5s')
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:294: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-12-14 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
# !python train.py --img 320 --batch 16 --epochs 499 --data dataset.yaml --weights yolov5s.pt --worker 2
# Out:
# 2023-12-14 07:04:39.761309: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-14 07:04:39.761373: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-14 07:04:39.761469: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
pwd
# Out:
# '/content/gdrive/MyDrive/EMO_1/yolov5'

# %%
# %cd runs
# Out:
# /content/gdrive/MyDrive/EMO_1/yolov5/runs

# %%
# %cd train
# Out:
# /content/gdrive/MyDrive/EMO_1/yolov5/runs/train

# %%
# %cd exp2
# Out:
# /content/gdrive/MyDrive/EMO_1/yolov5/runs/train/exp2

# %%
# %cd weights
# Out:
# /content/gdrive/MyDrive/EMO_1/yolov5/runs/train/exp2/weights

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path= 'last.pt' , force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-12-14 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7061368 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
import os

# %%
pwd
# Out:
# '/content/gdrive/MyDrive/EMO_1/yolov5/runs/train/exp2/weights'

# %%
# %cd ..
# Out:
# /content/gdrive/MyDrive/EMO_1/yolov5/runs/train/exp2

# %%
# %cd ..
# Out:
# /content/gdrive/MyDrive/EMO_1/yolov5/runs/train

# %%
# %cd ..
# Out:
# /content/gdrive/MyDrive/EMO_1/yolov5/runs

# %%
# %cd ..
# Out:
# /content/gdrive/MyDrive/EMO_1/yolov5

# %%
# %cd ..
# Out:
# /content/gdrive/MyDrive/EMO_1

# %%
ls
# Out:
# data/  yolov5/

# %%
# %cd data/images/
# Out:
# /content/gdrive/MyDrive/EMO_1/data/images

# %%
# jpg file are giving error of not valid images so we are using sample png images for further process

# To check if the image is valid or not

import PIL.Image
try:
    PIL.Image.open('/content/gdrive/MyDrive/EMO_1/data/happy_WIN_20231214_13_24_31_Pro_UU.png')
except PIL.UnidentifiedImageError:
    print('The image file is not a valid image file.')

# %%
img_1 = os.path.join('/content/gdrive/MyDrive/EMO_1/data/happy_WIN_20231214_13_24_31_Pro_UU.png')

# %%
img_1
# Out:
# '/content/gdrive/MyDrive/EMO_1/data/happy_WIN_20231214_13_24_31_Pro_UU.png'

# %%
result_1 = model(img_1)

# %%
result_1
# Out:
# YOLOv5 <class 'models.common.Detections'> instance
# image 1/1: 720x1280 1 happy
# Speed: 49.5ms pre-process, 8.2ms inference, 1.5ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(result_1.render()))
plt.show()

# %%
img_2 = ('/content/gdrive/MyDrive/EMO_1/data/neutral_WIN_20231214_13_42_14_Pro_UU.png')

# %%
result_2 = model(img_2)

# %%
result_2
# Out:
# YOLOv5 <class 'models.common.Detections'> instance
# image 1/1: 720x1280 1 neutral
# Speed: 65.6ms pre-process, 13.2ms inference, 2.3ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(result_2.render()))
plt.show()

# %%
img_3 = ('/content/gdrive/MyDrive/EMO_1/data/sad_WIN_20231214_13_42_23_Pro_UU.png')

# %%
result_3 = model(img_3)

# %%
result_3
# Out:
# YOLOv5 <class 'models.common.Detections'> instance
# image 1/1: 720x1280 1 neutral
# Speed: 143.7ms pre-process, 15.4ms inference, 8.9ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(result_3.render()))
plt.show()
